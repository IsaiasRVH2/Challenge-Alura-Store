# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 0. Preparación de los datos

# %%
tienda.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda2.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda3.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda4.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda.describe()
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.359000e+03     2359.000000   2359.000000         2359.000000
# mean   4.878679e+05    26018.609580      3.976685            2.943196
# std    6.146868e+05    32860.001783      1.415370            2.819897
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.575000e+04     3100.000000      3.000000            1.000000
# 50%    2.353000e+05    12400.000000      5.000000            1.000000
# 75%    6.781000e+05    36000.000000      5.000000            4.000000
# max    2.977000e+06   160800.000000      5.000000           24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean      5.365283   -74.789417
# std       2.287445     1.217827
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %%
tienda2.describe()
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.359000e+03     2359.000000   2359.000000         2359.000000
# mean   4.732274e+05    25216.235693      4.037304            2.902501
# std    5.955595e+05    31741.375166      1.356153            2.848416
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.455000e+04     2900.000000      4.000000            1.000000
# 50%    2.182000e+05    11600.000000      5.000000            1.000000
# 75%    6.777000e+05    35450.000000      5.000000            4.000000
# max    2.953400e+06   162500.000000      5.000000           24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean      5.499753   -74.742963
# std       2.351118     1.185997
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %%
tienda3.describe()
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.359000e+03     2359.000000   2359.000000         2359.000000
# mean   4.654598e+05    24805.680373      4.048326            2.967783
# std    5.806434e+05    30945.889626      1.386426            2.812153
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.740000e+04     3100.000000      4.000000            1.000000
# 50%    2.263000e+05    11900.000000      5.000000            2.000000
# 75%    6.660500e+05    34950.000000      5.000000            4.000000
# max    2.968200e+06   158400.000000      5.000000           24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean      5.437076   -74.733463
# std       2.405272     1.224572
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %%
tienda4.describe()
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.358000e+03     2358.000000   2358.000000         2358.000000
# mean   4.403629e+05    23459.457167      3.995759            2.896098
# std    5.687556e+05    30279.100836      1.403063            2.730393
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.340000e+04     2900.000000      3.000000            1.000000
# 50%    2.094500e+05    10950.000000      5.000000            1.000000
# 75%    6.342250e+05    33300.000000      5.000000            4.000000
# max    2.902200e+06   154700.000000      5.000000           18.000000
#
#                lat          lon
# count  2358.000000  2358.000000
# mean      5.413519   -74.774597
# std       2.376728     1.199749
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %% [markdown]
# # 1. Análisis de facturación

# %%
colors = ['#36565c','#1c8165','#7aa133','#ffa600']

ingresos_tienda = tienda['Precio'].sum()/1000000
ingresos_tienda2 = tienda2['Precio'].sum()/1000000
ingresos_tienda3 = tienda3['Precio'].sum()/1000000
ingresos_tienda4 = tienda4['Precio'].sum()/1000000
ingresos = (ingresos_tienda, ingresos_tienda2, ingresos_tienda3, ingresos_tienda4)


plt.figure(figsize=(10, 6))
plt.pie(ingresos, colors=colors, autopct='%1.1f%%', counterclock=False, startangle=140)
plt.title('Distribución de Ingresos por Tienda')
plt.legend(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], loc='right', bbox_to_anchor=(1.3, 0.5))
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda1_mas_vendidos = tienda['Categoría del Producto'].value_counts().sort_values(ascending=False).to_dict()
tienda2_mas_vendidos = tienda2['Categoría del Producto'].value_counts().sort_values(ascending=False).to_dict()
tienda3_mas_vendidos = tienda3['Categoría del Producto'].value_counts().sort_values(ascending=False).to_dict()
tienda4_mas_vendidos = tienda4['Categoría del Producto'].value_counts().sort_values(ascending=False).to_dict()

mas_vendidos = pd.DataFrame({
    'Tienda 1': tienda1_mas_vendidos,
    'Tienda 2': tienda2_mas_vendidos,
    'Tienda 3': tienda3_mas_vendidos,
    'Tienda 4': tienda4_mas_vendidos
})

categorias_mas_vendidas = mas_vendidos.sum(axis=1).sort_values(ascending=False).index.tolist()[:3]
mas_vendidos.loc[categorias_mas_vendidas].plot.bar(figsize=(10,6), color=colors)
plt.title('Categorías Más Vendidos Por Tienda')
# Out:
# Text(0.5, 1.0, 'Categorías Más Vendidos Por Tienda')

# %%
tienda1_menos_vendidos = tienda['Categoría del Producto'].value_counts().sort_values(ascending=True).to_dict()
tienda2_menos_vendidos = tienda2['Categoría del Producto'].value_counts().sort_values(ascending=True).to_dict()
tienda3_menos_vendidos = tienda3['Categoría del Producto'].value_counts().sort_values(ascending=True).to_dict()
tienda4_menos_vendidos = tienda4['Categoría del Producto'].value_counts().sort_values(ascending=True).to_dict()

menos_vendidos = pd.DataFrame({
    'Tienda 1': tienda1_menos_vendidos,
    'Tienda 2': tienda2_menos_vendidos,
    'Tienda 3': tienda3_menos_vendidos,
    'Tienda 4': tienda4_menos_vendidos
})

categorias_menos_vendidas = menos_vendidos.sum(axis=1).sort_values(ascending=True).index.tolist()[:3]
menos_vendidos.loc[categorias_menos_vendidas].plot.bar(figsize=(10,6), color=colors)
plt.title('Categorías Menos Vendidos Por Tienda')
# Out:
# Text(0.5, 1.0, 'Categorías Menos Vendidos Por Tienda')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
satisfaccion_tienda = tienda['Calificación'].mean()
satisfaccion_tienda2 = tienda2['Calificación'].mean()
satisfaccion_tienda3 = tienda3['Calificación'].mean()
satisfaccion_tienda4 = tienda4['Calificación'].mean()
satisfaccion = [satisfaccion_tienda, satisfaccion_tienda2, satisfaccion_tienda3, satisfaccion_tienda4]

plt.figure(figsize=(8,5))
plt.bar(["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"], satisfaccion, color=colors, edgecolor='black')

plt.xlabel('Calificación')
plt.ylabel('Tiendas')
plt.title('Calificación Promedio por Tienda')
plt.yticks([1, 2, 3, 4, 5])

for i, v in enumerate(satisfaccion):
    plt.text(i, v + 0.05, f"{v:.2f}", ha='center', fontweight='bold')

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
ventas_por_producto_tienda = tienda.Producto.value_counts()
ventas_por_producto_tienda2 = tienda2.Producto.value_counts()
ventas_por_producto_tienda3 = tienda3.Producto.value_counts()
ventas_por_producto_tienda4 = tienda4.Producto.value_counts()

# %%
print("Productos más vendidos Tienda 1:")
ventas_por_producto_tienda.sort_values(ascending=False).head(3)
# Out:
# Productos más vendidos Tienda 1:
# Producto
# Microondas       60
# TV LED UHD 4K    60
# Armario          60
# Name: count, dtype: int64

# %%
print("Productos menos vendidos Tienda 1:")
ventas_por_producto_tienda.sort_values(ascending=True).head(3)
# Out:
# Productos menos vendidos Tienda 1:
# Producto
# Auriculares con micrófono    33
# Celular ABXY                 33
# Olla de presión              35
# Name: count, dtype: int64

# %%
print("Productos más vendidos Tienda 2:")
ventas_por_producto_tienda2.sort_values(ascending=False).head(3)
# Out:
# Productos más vendidos Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Name: count, dtype: int64

# %%
print("Productos menos vendidos Tienda 2:")
ventas_por_producto_tienda2.sort_values(ascending=True).head(3)
# Out:
# Productos menos vendidos Tienda 2:
# Producto
# Juego de mesa      32
# Mesa de comedor    34
# Impresora          34
# Name: count, dtype: int64

# %%
print("Productos más vendidos Tienda 3:")
ventas_por_producto_tienda3.sort_values(ascending=False).head(3)
# Out:
# Productos más vendidos Tienda 3:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Name: count, dtype: int64

# %%
print("Productos menos vendidos Tienda 3:")
ventas_por_producto_tienda3.sort_values(ascending=True).head(3)
# Out:
# Productos menos vendidos Tienda 3:
# Producto
# Bloques de construcción    35
# Microondas                 36
# Set de vasos               36
# Name: count, dtype: int64

# %%
print("Productos más vendidos Tienda 4:")
ventas_por_producto_tienda4.sort_values(ascending=False).head(3)
# Out:
# Productos más vendidos Tienda 4:
# Producto
# Cama box                   62
# Cubertería                 59
# Dashboards con Power BI    56
# Name: count, dtype: int64

# %%
print("Productos menos vendidos Tienda 4:")
ventas_por_producto_tienda4.sort_values(ascending=True).head(3)
# Out:
# Productos menos vendidos Tienda 4:
# Producto
# Guitarra eléctrica    33
# Armario               34
# Guitarra acústica     37
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tienda1_promedio_envio = tienda['Costo de envío'].mean()
tienda2_promedio_envio = tienda2['Costo de envío'].mean()
tienda3_promedio_envio = tienda3['Costo de envío'].mean()
tienda4_promedio_envio = tienda4['Costo de envío'].mean()
promedio_envio = [tienda1_promedio_envio, tienda2_promedio_envio, tienda3_promedio_envio, tienda4_promedio_envio]
plt.figure(figsize=(8,5))
plt.bar(["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"], promedio_envio, color=colors, edgecolor='black')
plt.xlabel('Tiendas')
plt.ylabel('Costo de Envío Promedio')
plt.title('Costo de Envío Promedio por Tienda')
for i, v in enumerate(promedio_envio):
    plt.text(i, v + 0.5, f"${v:.2f}", ha='center', fontweight='bold')

# %% [markdown]
# # 6. Informe Final

# %% [markdown]
# Se realizó un análisis de las cuatro tiendas del Sr. Juan, teniendo en cuenta las métricas de facturación total, categorías más y menos populares, las evaluaciones recibidas de los clientes, los productos más y menos vendidos, y el costo de envió promedio para cada tienda. Después de la evaluación de estos puntos podemos afirmar que:
#
# **Ingresos Totales**: La *tienda 1* representa el porcentaje mayor en las ventas de las cuatro tiendas con un *26.1%* del total de ventas. Mientras que del lado contrario la *tienda 4* es la que aporta un menor porcentaje a los ingresos totales con tan solo un *23.6%* del total de ventas.
#
# **Categorías de productos más y menos vendidas**: Las categorías mas populares en las tiendas son las de *muebles* y *electrónicos*, con valores muy similares. Para estas categorías destaca especialmente la *tienda 3* que concentra el mayor volúmen de ventas para ambas, mientras que la *tienda 2* es la que presenta una menor cantidad de ventas para estas categorías. Por su parte, las categorías menos vendidas son las de *artículos para el hogar*, *libros* e *instrumentos musicales*.
#
# **Calificación promedio**: La calificación promedio para las tiendas es muy similar entre si, con una diferencia de tan solo *0.07* entre la mejor y la peor tienda en una escala del 0 al 5. En este apartado destaca la *tienda 3*, con una calificación promedio de *4.05*, mientras que la *tienda 1* presenta la calificación más baja con un *3.98*.
#
# **Productos más y menos vendidos**: Si bien, este rubro presenta la mayor variedad, podemos destacar al *microondas* como un producto que aparece entre los más vendidos en dos de las cuatro tiendas.
#
# **Costo promedio de envío**: El costo promedio de envío en todas las tiendas esta escalonado, destacando la *tienda 4* como la tienda con el envío promedio más bajo siendo de tan solo *$23,459.46*, mientras que la *tienda 1* presenta el costo de envío mas alto, costando en promedio *26,018.61* por envío. Sin embargo esto puede estar influenciado por el tipo de productos que son los más vendidos, ya que en la *tienda 1* los tres productos más vendidos son *muebles* o *electronicos*, mientras que en la *tienda 4* uno de los productos más vendidos es un libro.
#
# **Resolución final**
# Habiendo analizado las metricas se llego a la conclusión de que lo que supondría un mayor beneficio sería el **vender la tienda 4**, ya que en lo unico que destaca es en el menor costo de envió, cosa que como ya se comento podría estar influenciada por tener un libro como uno de sus productos más vendidos. La *tienda 4* es la que representa un menor porcentaje de los ingresos, que aunque tiene una calificación un poco mejor que la de la *tienda 1*, la tienda con mayor participación en los ingresos, esto no es lo suficientemente significativo comparado con la diferencia de ingresos.
